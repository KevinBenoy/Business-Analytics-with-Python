# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinBenoy/Business-Analytics-with-Python/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
d=pd.read_csv("Supermarket_sales.csv")

# %%
d
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
d.groupby("Unitprice").max()
# Out:
#             No    InvoiceID Branch       City Customertype  Gender  \
# Unitprice
# 10.08      945  333-23-2632      A     Yangon       Member    Male
# 10.13      573  239-48-4278      A     Yangon       Member    Male
# 10.16      785  516-77-6464      C  Naypyitaw       Member  Female
# 10.17      823  784-21-9238      C  Naypyitaw       Member    Male
# 10.18      882  115-38-7388      C  Naypyitaw       Member  Female
# ...        ...          ...    ...        ...          ...     ...
# 99.82      942  702-83-5291      C  Naypyitaw       Normal    Male
# 99.83      284  667-92-0055      A     Yangon       Member    Male
# 99.89      495  437-53-3084      B   Mandalay       Normal    Male
# 99.92      931  641-62-7288      B   Mandalay       Normal    Male
# 99.96      984  219-22-9386      C  Naypyitaw       Normal    Male
#
#                    Productline  Quantity      Tax     Total        Date  \
# Unitprice
# ...

# %%
d.groupby("Unitprice").min()
# Out:
#             No    InvoiceID Branch       City Customertype  Gender  \
# Unitprice
# 10.08      945  333-23-2632      A     Yangon       Member    Male
# 10.13      573  239-48-4278      A     Yangon       Member    Male
# 10.16      785  516-77-6464      C  Naypyitaw       Member  Female
# 10.17      823  784-21-9238      C  Naypyitaw       Member    Male
# 10.18      882  115-38-7388      C  Naypyitaw       Member  Female
# ...        ...          ...    ...        ...          ...     ...
# 99.82      301  446-47-6729      C  Naypyitaw       Member    Male
# 99.83      284  667-92-0055      A     Yangon       Member    Male
# 99.89      495  437-53-3084      B   Mandalay       Normal    Male
# 99.92      931  641-62-7288      B   Mandalay       Normal    Male
# 99.96      123  148-41-7930      B   Mandalay       Member    Male
#
#                    Productline  Quantity      Tax     Total        Date  \
# Unitprice
# ...

# %%
d.Unitprice.max()
# Out:
# 99.96

# %%
d.Unitprice.min()
# Out:
# 10.08

# %%
d.Unitprice.mean()
# Out:
# 55.67213

# %%
d.Quantity.min()
# Out:
# 1

# %%
d.Quantity.max()
# Out:
# 10

# %%
d.Quantity.mean()
# Out:
# 5.51

# %%
d.groupby("Productline").max("Health and beauty")
# Out:
#                           No  Unitprice  Quantity      Tax      Total    cogs  \
# Productline
# Electronic accessories   995      99.73        10  44.8785   942.4485  897.57
# Fashion accessories     1000      99.89        10  49.6500  1042.6500  993.00
# Food and beverages       998      99.79        10  49.2600  1034.4600  985.20
# Health and beauty        996      99.96        10  45.2500   950.2500  905.00
# Home and lifestyle       999      99.92        10  48.7500  1023.7500  975.00
# Sports and travel        992      99.96        10  47.7200  1002.1200  954.40
#
#                         gross_margin_percentage  gross_iincome  Rating
# Productline
# Electronic accessories                 4.761905        44.8785    10.0
# Fashion accessories                    4.761905        49.6500     9.9
# Food and beverages                     4.761905        49.2600     9.9
# Health and beauty                      4.761905        45.2500    10.0
# ...

# %%
d.groupby("Productline").min("Health and beauty")
# Out:
#                         No  Unitprice  Quantity     Tax    Total   cogs  \
# Productline
# Electronic accessories   2      10.56         1  1.2725  26.7225  25.45
# Fashion accessories     11      10.18         1  0.6045  12.6945  12.09
# Food and beverages      10      10.13         1  1.0790  22.6590  21.58
# Health and beauty        1      10.08         1  0.8875  18.6375  17.75
# Home and lifestyle       3      10.53         1  0.6990  14.6790  13.98
# Sports and travel        5      10.17         1  0.5085  10.6785  10.17
#
#                         gross_margin_percentage  gross_iincome  Rating
# Productline
# Electronic accessories                 4.761905         1.2725     4.0
# Fashion accessories                    4.761905         0.6045     4.0
# Food and beverages                     4.761905         1.0790     4.0
# Health and beauty                      4.761905         0.8875     4.0
# Home and lifestyle                     4.761905         0.6990     4.1
# ...

# %%
d.groupby("Quantity").mean("Health and beauty")
# Out:
#                   No  Unitprice        Tax       Total        cogs  \
# Quantity
# 1         541.839286  54.781875   2.739094   57.520969   54.781875
# 2         525.131868  57.534286   5.753429  120.822000  115.068571
# 3         544.600000  56.725556   8.508833  178.685500  170.176667
# 4         499.633028  55.150550  11.030110  231.632312  220.602202
# 5         466.215686  50.516176  12.629044  265.209926  252.580882
# 6         463.357143  55.806939  16.742082  351.583714  334.841633
# 7         521.274510  58.242843  20.384995  428.084897  407.699902
# 8         492.882353  56.465412  22.586165  474.309459  451.723294
# 9         456.945652  56.111630  25.250234  530.254908  505.004674
# 10        491.478992  55.965546  27.982773  587.638235  559.655462
#
#           gross_margin_percentage  gross_iincome    Rating
# Quantity
# 1                        4.761905       2.739094  7.001786
# 2                        4.761905       5.753429  6.860440
# ...

# %%
d.groupby("Productline").max("Health and beauty")
# Out:
#                           No  Unitprice  Quantity      Tax      Total    cogs  \
# Productline
# Electronic accessories   995      99.73        10  44.8785   942.4485  897.57
# Fashion accessories     1000      99.89        10  49.6500  1042.6500  993.00
# Food and beverages       998      99.79        10  49.2600  1034.4600  985.20
# Health and beauty        996      99.96        10  45.2500   950.2500  905.00
# Home and lifestyle       999      99.92        10  48.7500  1023.7500  975.00
# Sports and travel        992      99.96        10  47.7200  1002.1200  954.40
#
#                         gross_margin_percentage  gross_iincome  Rating
# Productline
# Electronic accessories                 4.761905        44.8785    10.0
# Fashion accessories                    4.761905        49.6500     9.9
# Food and beverages                     4.761905        49.2600     9.9
# Health and beauty                      4.761905        45.2500    10.0
# ...

# %%
d["Quantity"].loc[d["Productline"]=="Health and beauty"].max()
# Out:
# 10

# %%
d["Unitprice"].loc[d["Productline"]=="Health and beauty"].max()
# Out:
# 99.96

# %%
d["Quantity"].loc[d["Productline"]=="Health and beauty"].min()
# Out:
# 1

# %%
d.loc[d["Productline"]=="Health and beauty"].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# No                         495.532895
# Unitprice                   54.854474
# Quantity                     5.618421
# Tax                         15.411572
# Total                      323.643020
# cogs                       308.231447
# gross_margin_percentage      4.761905
# gross_iincome               15.411572
# Rating                       7.003289
# dtype: float64

# %%
d["Unitprice"].loc[d["Productline"]=="Health and beauty"].min()
# Out:
# 10.08

# %%
d['Quantity'].loc[(d["Productline"]=="Health and beauty") & (d["Gender"]=="Male")].count()
# Out:
# 88

# %%
d
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
d['Quantity'].loc[d['City']=='Yangon']
# Out:
# 0      7
# 2      7
# 3      8
# 4      7
# 6      6
#       ..
# 990    5
# 992    2
# 997    1
# 998    1
# 999    7
# Name: Quantity, Length: 340, dtype: int64

# %%
import matplotlib as plt

# %%
d.loc[(d["Productline"]=="Fashion accessories") & (d["Gender"]=="Female")].count()
# Out:
# No                         96
# InvoiceID                  96
# Branch                     96
# City                       96
# Customertype               96
# Gender                     96
# Productline                96
# Unitprice                  96
# Quantity                   96
# Tax                        96
# Total                      96
# Date                       96
# Time                       96
# Payment                    96
# cogs                       96
# gross_margin_percentage    96
# gross_iincome              96
# Rating                     96
# dtype: int64

# %%
d["Quantity"].loc[(d["Productline"]=="Fashion accessories") | (d["Productline"]=="Sports and travel") | (d["Gender"]=="Female")].count()
# Out:
# 661

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(d['Tax'],d['Quantity'])

# %%
d
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
import pandas as pd
d["Tax"].loc[d['City']=="Yangon"].sum()
# Out:
# 5057.1605

# %%
x=d["Quantity"].loc[d["City"]=="Yangon"].sum()

# %%
y=d["Quantity"].loc[d["City"]=="Mandalay"].sum()

# %%
if x>y:
  print("Yangon has more sales than Mandalay")
else:
  print("Mandalay has more sales than Yangon")
# Out:
# Yangon has more sales than Mandalay

# %%
d
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
d
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
x=d.gross_iincome.min()
print(d['InvoiceID'].loc[d['gross_iincome']==x])
import matplotlib.pyplot as plt
plt.plot(d['Unitprice'],d['Tax'])
# Out:
# 822    784-21-9238
# Name: InvoiceID, dtype: object

# %%
d.groupby('gross_iincome').min()
# Out:
#                 No    InvoiceID Branch       City Customertype  Gender  \
# gross_iincome
# 0.5085         823  784-21-9238      C  Naypyitaw       Member    Male
# 0.6045         630  308-39-1707      A     Yangon       Normal  Female
# 0.6270         224  279-62-1445      C  Naypyitaw       Member  Female
# 0.6390         444  192-98-7397      C  Naypyitaw       Normal    Male
# 0.6990         403  236-86-3015      C  Naypyitaw       Member    Male
# ...            ...          ...    ...        ...          ...     ...
# 48.6900        997  303-96-2227      B   Mandalay       Normal  Female
# 48.7500        700  751-41-9720      C  Naypyitaw       Normal    Male
# 49.2600        558  283-26-5248      C  Naypyitaw       Member  Female
# 49.4900        168  687-47-8271      A     Yangon       Normal    Male
# 49.6500        351  860-79-0874      C  Naypyitaw       Member  Female
#
#                        Productline  Unitprice  Quantity      Tax      Total  \
# gross_iincome
# ...

# %%
x=d['gross_margin_percentage'].loc[(d['Gender']=="Male")].max()
y=d['gross_margin_percentage'].loc[(d['Gender']=="Female")].max()
if x>y:
  print("Males have more profit margin")
elif y>x:
  print("Females have more profit margin")
else:
  print("Both males and females have the same profit margin")
# Out:
# Both males and females have the same profit margin

# %%
plt.plot(d['Rating'],d['Unitprice'])
x=d['Rating'].loc[d['Gender']=='Male'].max()
y=d['Rating'].loc[d['Gender']=='Female'].max()
if x>y:
  print("Males have more rating")
elif x<y:
  print("Females have more rating")
else:
  print("Both have the same rating")
# Out:
# Both have the same rating

# %%
d
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
x=d['gross_iincome'].max()
c=d['Customertype'].loc[d['gross_iincome']==x]
print(c)
if c.equals("Member"):
  print("Being a member is better")
else:
  print("Being normal is better")
# Out:
# 350    Member
# Name: Customertype, dtype: object
# Being normal is better
